# %%
username = "marco"
username_hex = username.encode("utf-8")

"USER:marco______CREDIT:10000" 
"CREDIT:10_______"


"USER:marco______CREDIT:10_______"
ae6610c0280d90ae507bdf46faf1a506e
c9076b39b19095d09618bd6dcf58f97


"USER:aaaaa______CREDIT:10_______"
4f6175d266b47c87197cc4d6bffd1e76e
c9076b39b19095d09618bd6dcf58f97
# Out:
# b'3a59199030d09eac77eca1bf765a0e6eec9076b39b19095d09618bd6dcf58f97'
# b'marco'
# b'ae6610c0280d90ae507bdf46faf1a506ec9076b39b19095d09618bd6dcf58f97'

# %%
voucher = "3a59199030d09eac77eca1bf765a0e6eec9076b39b19095d09618bd6dcf58f97"
voucher_enc = voucher.encode("utf-8")
# Out:
# b'marco'

# %%
ustest = "astros"
votest = "ae6610c0280d90ae507bdf46faf1a506ec9076b39b19095d09618bd6dcf58f97"
voucher_enc_t = votest.encode("utf-8")
